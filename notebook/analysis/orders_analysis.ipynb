# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
orders = pd.read_csv('../../../data/orders.csv')

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81282 entries, 0 to 81281
# Data columns (total 25 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          81282 non-null  int64
#  1   id                  81282 non-null  int64
#  2   drug_id             81282 non-null  int64
#  3   invoice_id          81282 non-null  int64
#  4   customer_id         81282 non-null  int64
#  5   buying_price        81282 non-null  int64
#  6   price               81282 non-null  int64
#  7   has_discount        81282 non-null  int64
#  8   quantity            81282 non-null  int64
#  9   amount              81282 non-null  int64
#  10  discount            81282 non-null  int64
#  11  discount_total      81282 non-null  int64
#  12  refund              81282 non-null  int64
#  13  refund_reason       0 non-null      float64
#  14  refund_notice       0 non-null      float64
# ...

# %%
# drug category when included can provide information on what category is highly demanded
orders['drug_id'].value_counts()
# Out:
# 2465    1098
# 278      780
# 1918     749
# 146      702
# 159      647
#         ...
# 844        1
# 102        1
# 2280       1
# 109        1
# 2903       1
# Name: drug_id, Length: 1733, dtype: int64

# %%
orders.groupby('drug_id').customer_id.count().sort_values(ascending=False)
# Out:
# drug_id
# 2465    1098
# 278      780
# 1918     749
# 146      702
# 159      647
#         ...
# 1637       1
# 1623       1
# 1610       1
# 1583       1
# 2          1
# Name: customer_id, Length: 1733, dtype: int64

# %%
orders.groupby(['customer_id']).drug_id.count()
# Out:
# customer_id
# 1       246
# 4        38
# 5        79
# 6       482
# 7         1
#        ...
# 2129      2
# 2134    107
# 2136      2
# 2138      7
# 2139      3
# Name: drug_id, Length: 682, dtype: int64

# %%
orders.head()
# Out:
#    Unnamed: 0  id  drug_id  invoice_id  customer_id  buying_price  price  \
# 0           0   1     1279           1            1             0   1342
# 1           1   2     1279           2            1             0   1342
# 2           2   3     2082           3            1             0   1006
# 3           3   4      262           4            1             0   1118
# 4           4   5     2257           5            1             0   1211
#
#    has_discount  quantity  amount  ...  returned_items  is_refunded  total  \
# 0             0         1    1342  ...               0            0   1342
# 1             0         1    1342  ...               0            0   1342
# 2             0         1    1006  ...               0            0   1006
# 3             0         1    1118  ...               0            0   1118
# 4             0         1    1211  ...               0            0   1211
#
# ...

# %%
orders[orders['is_confirmed']==1]
# Out:
#      Unnamed: 0   id  drug_id  invoice_id  customer_id  buying_price  price  \
# 121         121  171     1793         107           33             0  11708
# 122         122  172      556         107           33             0   6373
# 123         123  173     2396         107           33             0  14087
#
#      has_discount  quantity  amount  ...  returned_items  is_refunded  total  \
# 121             0         1   11708  ...               0            0  11708
# 122             0         2   12746  ...               0            0  12746
# 123             0         1   14087  ...               0            0  14087
#
#      total_buying_price  packed_quantity  packed_total  is_packed  \
# 121                   0                0             0          1
# 122                   0                0             0          1
# 123                   0                0             0          1
#
#      is_confirmed           created_at           updated_at
# ...
